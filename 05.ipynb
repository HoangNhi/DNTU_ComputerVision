# %%
from PIL import Image
from imgTools import *

# %%
my_path = 'C:/Users/hoang/Desktop/Image/MyRoom.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>

# %%
region = (100, 100, 175, 175)

# %%
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x75>

# %%
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>

# %%
# Xoay ảnh nhưng vẫn giữ kích thước khung ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=736x414>

# %%
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=736x414>

# %%
# Transpose ảnh nội dung và xoay luôn khung ảnh
transposed_img = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=414x736>

# %%
# Transpose ảnh
transposed_img = transposed_img.transpose(Image.Transpose.ROTATE_90)
display(transposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=736x414>
