# %%
# Shift + Enter: run đoạn code, sau đó thêm dòng mới

# %%
# Ctrl + Enter: chỉ run đoạn code

# %%
# Cài đặt
# !pip install Pillow
# !conda install Pillow

# %%
#Import thư viện
from PIL import Image
#Import from File imgTools.py
from imgTools import *

# %%
# Thư mục chứa ảnh
# Trong python dùng dấu / thay cho \\
import os
print(os.getcwd())
# Đường dẫn chứa ảnh
my_path = 'C:/Users/hoang/Desktop/Image/MyRoom.jpg'
dir = 'C:/Users/hoang/Desktop/Image'
# Out:
# C:\Users\hoang\Desktop\Learning\DNTU_ComputerVision

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>

# %%
print(img.size)
# Out:
# (736, 414)

# %%
# Thay đổi kích thước hình ảnh
new_size = (1000, 1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Lưu hình ảnh resize
new_img_risize_path = dir + "/new_img_resize.JPG"
new_image.save(new_img_risize_path)

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x28>

# %%
# Lưu hình ảnh resize
new_img_thumbnail_path = dir + "/new_img_thumbnail.JPG"
img.save(new_img_thumbnail_path)
