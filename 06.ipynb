# %%
from PIL import Image
from imgTools import *

# %%
my_path = 'C:/Users/hoang/Desktop/Image/MyRoom.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>

# %% [raw]
# gray_image = img.convert("L")
# display(gray_image)

# %%
# Phân RGB thành 3 tầng màu
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=736x414>
# <PIL.Image.Image image mode=L size=736x414>
# <PIL.Image.Image image mode=L size=736x414>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=736x414>
