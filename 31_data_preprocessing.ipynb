# %%
# Import các thư viện cần thiết
import numpy as np
import cv2
import pandas as pd
import os
import pickle
from google.colab import drive
from google.colab.patches import cv2_imshow

# %%
# Connect Google Drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/test_opencv/'
# Hiển thị tất cả thư mục hoặc file
os.listdir(path)
# Out:
# Mounted at /content/drive
# ['image_2260.jpg',
#  'image_2400.jpg',
#  'People.jpg',
#  'models',
#  '27.ipynb',
#  '30.ipynb',
#  'FaceImage',
#  'data_face_features.pickle',
#  '31_data_preprocessing.ipynb']

# %%
# Face detection model
faceDetectionModel = path + "/models/res10_300x300_ssd_iter_140000_fp16.caffemodel"

# Mô tả kiến trúc
faceDetectionProto = path + "/models/deploy.prototxt.txt"

# Mô hình mô tả khuôn mặt
faceDescriptor = path + "/models/openface.nn4.small2.v1.t7"

# Sử dụng OpenCV DNN đọc mô hình nhận diện khuôn mặt
dectectorModel = cv2.dnn.readNetFromCaffe(faceDetectionProto, faceDetectionModel)

# Đọc mô hình mô tả khuôn mặt từ file Torch
descriptorModel = cv2.dnn.readNetFromTorch(faceDescriptor)

# %%
# Danh sách hình ảnh chuẩn bị
faces = path + '/FaceImage'
os.listdir(faces)
# Out:
# ['1721031620_PhanQuocHuy',
#  '1721031695_DinhDuyLong',
#  '1721031731_NguyenDongHung',
#  '1721031591_NguyenHongNhung',
#  '1721031651_NguyenHoangKyAnh',
#  '1721031660_LeQuangQuocDat',
#  '1721031615_VuDinhNguyen',
#  '1721031618_TruongThanhLuan',
#  '1721031561_NguyenDucHieu',
#  '1721031693_HuynhMinhTien',
#  '1721031324_LeVanTrong',
#  '1721031488_PhamTheToan',
#  '1721031558_ThaiMinhTam',
#  '1721031457_BuiThiCaoDuyen',
#  '1721031512_LeMinhNghia',
#  '1721031314_NguyenDinhHao',
#  '1721031546_Tran Trung Hieu',
#  '1721031446_NguyenMinhKhanh',
#  '1721031416_NguyenTheHien',
#  '1721031460_NguyenDoanDucNam',
#  '1721031293_LeBaoHongDuc',
#  '1721031229_NinhVanDung',
#  '1721031129_TranAnhHao',
#  '1721031139_BaoNgocThienBao',
#  '1721031077_PhamNguyenPhuongTheNgoc',
#  '1721030985-PhamNgocKhanhVinh',
#  '1721031236_nguyenhoangtuan',
#  '1721031291_DaoHoangNhi',
#  '1721030961_NguyenPhuocSang',
#  '1721031276_ThachAnhQuoc',
#  '1721030881_ThanTrongPhuc',
#  '1721030848_LeQuocKy',
#  '1721030802_NguyenNhatTien',
#  '1721030943_DangMinhVu',
#  '1721030882_TranQuocLam',
#  '1721030861_VuQuocBao',
#  '1721030846_MaiHoTienLoc',
#  '1721030936-phamtrantrunghieu',
#  '1721030874_HoTuanDung',
#  '1721030867_TranDongAnh',
#  '1721030650_DangDucMinhQuang',
#  '1721030572_DoTruongPhatDat',
#  '1721030651_VuDinhLam',
#  '1721030646_NguyenThanhHienNguyen',
#  '1721030566_LeNguyenHoang',
#  '1721030593_NguyenThanhHai',
#  '1721030676_NguyenChauNhutPhi',
#  '1721030771_PhamNguyenHaiHuy',
#  '1721030799_NguyenNhatHieu',
#  '1721030687_TrinhDuyNghia',
#  '1721030548_VuNguyenQuocAn',
#  '1721030496_HaHuyPhuc',
#  '1721030493_DoVietHung',
#  '1721030489_VuNgocKyDuyen',
#  '1721030545_NguyenHoangTuanAnh',
#  '1721030456_Đào Ngọc Huy',
#  '1721030497_HoThienSinh',
#  '1721030491_Nguyễn Thế Nhật',
#  '1721030537-VoHuuThang',
#  '1721030544_TranQuangBinh',
#  '1721030453_NguyenVuThanhLong',
#  '1721030403_LeKhaHieu',
#  '1721021119_TranDuyHa',
#  '172100358_DoanVuBinhDuong',
#  '1721011379_TruongXuanHai',
#  '1721030420_TranVanManh',
#  '1721030368_lephuonglanh',
#  '1721030439_TranThanhBinh',
#  '1721030367_LePhuongLinh',
#  '1721030398_TranMinhQuang',
#  '172100264_NgoDangDuy',
#  '172100280_NguyenHoangQuan',
#  '172100337_HaDuyPhuong',
#  '172100257_LuongThanhPhong',
#  '172100357_LeQuangPhu',
#  '172100321_NguyenTrongNghia',
#  '172100326_DangVuTrangNguyen',
#  '172100251_NguỵenHaiDuy',
#  '172100304_LiuGiaLuan',
#  '172100309_TranCongSang',
#  '172100123_NguyenTrongAn',
#  '172100124_BuiMinhHieu',
#  '172100207_DuHieuBao',
#  '172100187_LeAnhQuan',
#  '172100103_tranquangthuan',
#  '172100201_NguyenThanhDat',
#  '172100177_DangNguyenThienAn',
#  '172100191_LeMinhKhoi',
#  '172100062_Trần_Nguyễn_Ngọc_Quý',
#  '172100095_NguyenTrungNghia',
#  '162000947_TranThanhDat',
#  '162001391_TranTien',
#  '1711031462_VanHuuDuc',
#  '172100043_NguyenHuuHa',
#  '172100041_HoangHuuDien',
#  '162001371_leminhtien',
#  '172100048_NguyenPhamAnhKhoa',
#  '162000651_NguyễnXuânNam',
#  '162000670_nguyenmanhthi',
#  '162000989_NguyenThanhSang',
#  '162000339_HuynhAnhDuy',
#  '162000223_ChuNguyenTienThanh',
#  '162000186_NguyenVanHuong',
#  '151901205_BuiKhanhBinh',
#  '162000309_LeHoangQuan']

# %%
# Tạo ra một functions để áp dụng cho nhiều ảnh
def myDetect(image_path):
  # Trích xuất đặc trưng cho một ảnh
  img1 = cv2.imread(image_path)

  # Copy cái ảnh
  image = img1.copy()

  # Lấy chiều cao và chiều rộng của ảnh
  h, w = image.shape[:2]

  # Chuẩn bị dữ liệu đầu vào cho mô hình nhận diện khuôn mặt
  imgBlob = cv2.dnn.blobFromImage(image, 1, (300,300), (104, 177, 123), swapRB=False, crop=False)

  # Thiết lập đầu vào cho mô hình
  dectectorModel.setInput(imgBlob)

  # Thực hiện việc nhận diện khuôn mặt
  detections = dectectorModel.forward()

  # Kiểm tra xem có khuôn mặt nào hay không?
  if (len(detections)>0):
    # Chọn khuôn mặt có độ tin cậy cao nhất (confidence) cao nhất
    i = np.argmax(detections[0, 0, :, 2]) # Giá trị thứ 2 trong 7 giá trị cuối cùng => confidence
    confidence = detections[0, 0, i, 2]

    # Kiểm tra độ tin cậy có lớn hơn 0.5
    if (confidence>0.5):
        # Tính toán hộp bao quanh khuôn mặt
        box = detections[0, 0, i, 3:7]* np.array([w, h, w, h])
        (startX, startY, endX, endY) =box.astype('int')

        # Trích xuất vùng ảnh chứa khuôn mặt ra
        roi = image[startY:endY, startX:endX]

        # Chuẩn bị dữ liệu đầu vào cho mô hình trích xuất đặc trưng
        faceBlob = cv2.dnn.blobFromImage(roi, 1/255, (96,96), (0,0,0), swapRB=True, crop=True)

        # Thiết lập đầu vào cho mô hình
        descriptorModel.setInput(faceBlob)

        # Thực hiện việc trích xuất đặc trưng
        vectors = descriptorModel.forward()

        # Print vectors
        return vectors

# %%
# Apply for all images
# Khởi tạo một dictionary
data = dict(data=[], label=[])

myDir = '/content/drive/MyDrive/test_opencv/FaceImage'
folders = os.listdir(myDir)

# Duyệt qua từng thư mục
for folder in folders:
  path = myDir + "/"+folder
  print(path)

  files = os.listdir(path)
  for fileName in files:
    try:
        # Gọi hàm trích xuất đặc trưng
        vector = myDetect(path+'/'+fileName)

        # Kiểm tra việc trích xuất đặc trưng thành công:
        if vector is not None:
          #Thêm vector đặc trưng vào trong từ điển với nhãn là tên của thư mục
          data['data'].append(vector)
          data['label'].append(folder)
          print('Trích xuất đặc trưng thành công')
    except:
      # Bỏ qua nếu gặp lỗi
      pass
# Out:
# /content/drive/MyDrive/test_opencv/FaceImage/1721031620_PhanQuocHuy
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031695_DinhDuyLong
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031731_NguyenDongHung
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031591_NguyenHongNhung
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031651_NguyenHoangKyAnh
# /content/drive/MyDrive/test_opencv/FaceImage/1721031660_LeQuangQuocDat
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031615_VuDinhNguyen
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031618_TruongThanhLuan
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031561_NguyenDucHieu
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031693_HuynhMinhTien
# /content/drive/MyDrive/test_opencv/FaceImage/1721031324_LeVanTrong
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031488_PhamTheToan
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031558_ThaiMinhTam
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031457_BuiThiCaoDuyen
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031512_LeMinhNghia
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031314_NguyenDinhHao
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031546_Tran Trung Hieu
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031446_NguyenMinhKhanh
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031416_NguyenTheHien
# /content/drive/MyDrive/test_opencv/FaceImage/1721031460_NguyenDoanDucNam
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031293_LeBaoHongDuc
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031229_NinhVanDung
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031129_TranAnhHao
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031139_BaoNgocThienBao
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031077_PhamNguyenPhuongTheNgoc
# /content/drive/MyDrive/test_opencv/FaceImage/1721030985-PhamNgocKhanhVinh
# /content/drive/MyDrive/test_opencv/FaceImage/1721031236_nguyenhoangtuan
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721031291_DaoHoangNhi
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721030961_NguyenPhuocSang
# /content/drive/MyDrive/test_opencv/FaceImage/1721031276_ThachAnhQuoc
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721030881_ThanTrongPhuc
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/1721030848_LeQuocKy
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# ...
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/172100041_HoangHuuDien
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/162001371_leminhtien
# /content/drive/MyDrive/test_opencv/FaceImage/172100048_NguyenPhamAnhKhoa
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/162000651_NguyễnXuânNam
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/162000670_nguyenmanhthi
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/162000989_NguyenThanhSang
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/162000339_HuynhAnhDuy
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/162000223_ChuNguyenTienThanh
# /content/drive/MyDrive/test_opencv/FaceImage/162000186_NguyenVanHuong
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/151901205_BuiKhanhBinh
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# /content/drive/MyDrive/test_opencv/FaceImage/162000309_LeHoangQuan
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công
# Trích xuất đặc trưng thành công

# %%
# Tạo một series từ dictionary
labelSeries = pd.Series(data['label'])
# Đếm số lần xuất hiện của mỗi nhãn
labelCounts = labelSeries.value_counts()
print(labelCounts)
# Out:
# 1721030566_LeNguyenHoang        150
# 1721030676_NguyenChauNhutPhi    137
# 1721030848_LeQuocKy             135
# 1721031129_TranAnhHao           130
# 1721030367_LePhuongLinh         124
#                                ...
# 172100251_NguỵenHaiDuy          10
# 1721030497_HoThienSinh            9
# 172100103_tranquangthuan          8
# 1721021119_TranDuyHa              6
# 1721030802_NguyenNhatTien         5
# Name: count, Length: 94, dtype: int64

# %%
# Save data -> file
print('/content/drive/MyDrive/test_opencv/')
fileName = '/content/drive/MyDrive/test_opencv/data_face_features.pickle'
pickle.dump(data, open(fileName, mode='wb'))
# Out:
# /content/drive/MyDrive/test_opencv/

# %%
pd.set_option('display.max_rows', None)  # Hiển thị tất cả các hàng
pd.set_option('display.max_columns', None) # Hiển thị tất cả các cột

# %%
print(labelCounts)
# Out:
# 1721030566_LeNguyenHoang            150
# 1721030676_NguyenChauNhutPhi        137
# 1721030848_LeQuocKy                 135
# 1721031129_TranAnhHao               130
# 1721030367_LePhuongLinh             124
# 172100257_LuongThanhPhong           121
# 1721030537-VoHuuThang               102
# 1721030874_HoTuanDung               102
# 1721031293_LeBaoHongDuc              96
# 1721011379_TruongXuanHai             96
# 1721030572_DoTruongPhatDat           93
# 1721031276_ThachAnhQuoc              89
# 1721031615_VuDinhNguyen              88
# 1721030687_TrinhDuyNghia             87
# 172100048_NguyenPhamAnhKhoa          84
# 172100201_NguyenThanhDat             83
# 172100041_HoangHuuDien               82
# 1721031561_NguyenDucHieu             79
# 1721030403_LeKhaHieu                 79
# 1721030936-phamtrantrunghieu         77
# 1721030548_VuNguyenQuocAn            76
# 1721031731_NguyenDongHung            74
# 1721030544_TranQuangBinh             69
# 1721030398_TranMinhQuang             67
# 1721030943_DangMinhVu                66
# 172100264_NgoDangDuy                 65
# 1721030799_NguyenNhatHieu            65
# 1721031512_LeMinhNghia               61
# 172100043_NguyenHuuHa                61
# 172100191_LeMinhKhoi                 60
# 172100337_HaDuyPhuong                58
# 172100187_LeAnhQuan                  58
# 162000186_NguyenVanHuong             58
# 1721031236_nguyenhoangtuan           58
# 1721031618_TruongThanhLuan           58
# 162000309_LeHoangQuan                56
# 1721030881_ThanTrongPhuc             56
# 1721031460_NguyenDoanDucNam          56
# 1721030846_MaiHoTienLoc              55
# 162000947_TranThanhDat               55
# 172100095_NguyenTrungNghia           55
# 1721030491_Nguyễn Thế Nhật     54
# 1721030456_Đào Ngọc Huy            52
# 172100358_DoanVuBinhDuong            52
# 1721031139_BaoNgocThienBao           50
# 1721031324_LeVanTrong                50
# 1721031314_NguyenDinhHao             50
# 1721031291_DaoHoangNhi               50
# 162000989_NguyenThanhSang            49
# 1721031229_NinhVanDung               45
# 1721030646_NguyenThanhHienNguyen     45
# 1721031620_PhanQuocHuy               44
# 162001391_TranTien                   42
# 162000651_NguyễnXuânNam           41
# 1721031558_ThaiMinhTam               40
# 162000339_HuynhAnhDuy                39
# 172100309_TranCongSang               38
# 162000670_nguyenmanhthi              37
# 1721030867_TranDongAnh               35
# 1721031446_NguyenMinhKhanh           33
# 1721030439_TranThanhBinh             31
# 1721031457_BuiThiCaoDuyen            31
# 172100326_DangVuTrangNguyen          30
# 1721030650_DangDucMinhQuang          24
# 1721030493_DoVietHung                23
# 1721030882_TranQuocLam               23
# 172100123_NguyenTrongAn              23
# 1721030496_HaHuyPhuc                 22
# 172100124_BuiMinhHieu                21
# 1721030420_TranVanManh               20
# 1721030453_NguyenVuThanhLong         19
# 1721031591_NguyenHongNhung           19
# 1721030368_lephuonglanh              18
# 1721031546_Tran Trung Hieu           18
# 1711031462_VanHuuDuc                 16
# 172100357_LeQuangPhu                 14
# 172100280_NguyenHoangQuan            14
# 1721030593_NguyenThanhHai            14
# 172100177_DangNguyenThienAn          14
# 1721031488_PhamTheToan               13
# 172100207_DuHieuBao                  12
# 1721031695_DinhDuyLong               12
# 1721030489_VuNgocKyDuyen             10
# 1721031660_LeQuangQuocDat            10
# 1721030861_VuQuocBao                 10
# 1721030545_NguyenHoangTuanAnh        10
# 151901205_BuiKhanhBinh               10
# 172100304_LiuGiaLuan                 10
# 172100321_NguyenTrongNghia           10
# 172100251_NguỵenHaiDuy              10
# 1721030497_HoThienSinh                9
# 172100103_tranquangthuan              8
# 1721021119_TranDuyHa                  6
# 1721030802_NguyenNhatTien             5
# Name: count, dtype: int64
