# %%
# Kết nối đến Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
path = '/content/drive/MyDrive/test_opencv'
# Hiển thị tất cả thư mục hoặc file
os.listdir(path)
# Out:
# ['image_2260.jpg',
#  'image_2400.jpg',
#  'People.jpg',
#  'models',
#  '27.ipynb',
#  '30.ipynb',
#  'FaceImage',
#  'data_face_features.pickle',
#  '31_data_preprocessing.ipynb',
#  '29.ipynb']

# %%
# Hiển thị một ảnh
img = cv2.imread(path + "/People.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=564x864>
